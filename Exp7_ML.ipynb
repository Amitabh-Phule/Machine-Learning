# %% [markdown]
# <a href="https://colab.research.google.com/github/Amitabh-Phule/Machine-Learning/blob/main/Exp7_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# **Load Dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/ml/SMS-Data.csv')
df.head()
# Out:
#   phoneNumber                                    id  \
# 0  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 1  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 2  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 3  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
# 4  xx39973810  baa1668c-049e-4118-938e-cc804f1e73aa
#
#                        updateAt senderAddress  \
# 0  Sat, 7 May 2022 19:48:00 UTC     JK-SmplPL
# 1  Sat, 7 May 2022 19:48:00 UTC     VP-ViCARE
# 2  Sat, 7 May 2022 19:48:00 UTC     VP-612345
# 3  Sat, 7 May 2022 19:48:00 UTC     BP-ACKOGI
# 4  Sat, 7 May 2022 19:48:00 UTC     VP-ViCARE
#
#                                                 text
# 0  Rs.95.15 on Zomato charged via Simpl.\r\n--\r\...
# 1  Hi! Update your email id through WhatsApp: htt...
# 2  Lucknow ya Kolkata ? - watch it LIVE with Vi c...
# 3  Mohd,\nCheck the incredible Acko insurance pol...
# 4  Hi! You can now get your Vi prepaid invoice em...

# %% [markdown]
# **Text Preprocessing**

# %%
import string
def clean_text(text):
    """Converts text to string, then lowercase and removes punctuation."""
    if not isinstance(text, str):
        text = str(text)
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))
    return text
df['cleaned_text'] = df['text'].apply(clean_text)
display(df[['text', 'cleaned_text']].head())
# Out:
#                                                 text  \
# 0  Rs.95.15 on Zomato charged via Simpl.\r\n--\r\...
# 1  Hi! Update your email id through WhatsApp: htt...
# 2  Lucknow ya Kolkata ? - watch it LIVE with Vi c...
# 3  Mohd,\nCheck the incredible Acko insurance pol...
# 4  Hi! You can now get your Vi prepaid invoice em...
#
#                                         cleaned_text
# 0  rs9515 on zomato charged via simpl\r\n\r\nfood...
# 1  hi update your email id through whatsapp https...
# 2  lucknow ya kolkata   watch it live with vi cri...
# 3  mohd\ncheck the incredible acko insurance poli...
# 4  hi you can now get your vi prepaid invoice ema...

# %% [markdown]
# **Feature Extraction (TF-IDF)**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer()
tfidf_features = tfidf_vectorizer.fit_transform(df['cleaned_text'])
print("Shape of TF-IDF features:", tfidf_features.shape)
# Out:
# Shape of TF-IDF features: (100243, 82623)

# %% [markdown]
# **Split Data**

# %%
from sklearn.model_selection import train_test_split
import numpy as np
df['label'] = np.random.randint(0, 2, size=len(df))
labels = df['label']
X_train, X_test, y_train, y_test = train_test_split(
    tfidf_features, labels, test_size=0.2, random_state=42)
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (80194, 82623)
# Shape of X_test: (20049, 82623)
# Shape of y_train: (80194,)
# Shape of y_test: (20049,)

# %% [markdown]
# **Train Naive Bayes Classifier**

# %%
from sklearn.naive_bayes import MultinomialNB
naive_bayes_model = MultinomialNB()
naive_bayes_model.fit(X_train, y_train)
print("Multinomial Naive Bayes model trained successfully.")
# Out:
# Multinomial Naive Bayes model trained successfully.

# %% [markdown]
# **Make Predictions**

# %%
y_pred = naive_bayes_model.predict(X_test)

# %% [markdown]
# **Evaluate Model**

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")

report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)
# Out:
# Accuracy: 0.4951
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.49      0.47      0.48      9964
#            1       0.50      0.52      0.51     10085
#
#     accuracy                           0.50     20049
#    macro avg       0.50      0.50      0.49     20049
# weighted avg       0.50      0.50      0.49     20049
